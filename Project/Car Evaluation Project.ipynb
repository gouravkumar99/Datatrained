# %%
#import python library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import data
data = pd.read_csv('car.csv')

# %%
#check first five rows
data.head()
# Out:
#    Unnamed: 0 buying  maint doors persons lug_boot safety  class
# 0           0  vhigh  vhigh     2       2    small    med  unacc
# 1           1  vhigh  vhigh     2       2    small   high  unacc
# 2           2  vhigh  vhigh     2       2      med    low  unacc
# 3           3  vhigh  vhigh     2       2      med    med  unacc
# 4           4  vhigh  vhigh     2       2      med   high  unacc

# %%
#check columns name
data.columns
# Out:
# Index(['Unnamed: 0', 'buying', 'maint', 'doors', 'persons', 'lug_boot',
#        'safety', 'class'],
#       dtype='object')

# %%
#drop row
data.drop(columns='Unnamed: 0',axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727 entries, 0 to 1726
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   buying    1727 non-null   object
#  1   maint     1727 non-null   object
#  2   doors     1727 non-null   object
#  3   persons   1727 non-null   object
#  4   lug_boot  1727 non-null   object
#  5   safety    1727 non-null   object
#  6   class     1727 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %%
data.describe()
# Out:
#        buying maint  doors persons lug_boot safety  class
# count    1727  1727   1727    1727     1727   1727   1727
# unique      4     4      4       3        3      3      4
# top      high  high  5more       4      med   high  unacc
# freq      432   432    432     576      576    576   1209

# %%
#check null values
data.isnull().sum()
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safety      0
# class       0
# dtype: int64

# %%
data.columns
# Out:
# Index(['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class'], dtype='object')

# %% [markdown]
# # Comparative Data Analysis

# %%
price = pd.crosstab(data['buying'], data['class'])
price.div(price.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = True, figsize = (10, 7))

plt.title('Stacked Bar Graph to Depict portions of Decisions taken on each buying Category', fontsize = 20)
plt.xlabel('buyingRange in Increasing Order', fontsize = 15)
plt.ylabel('Count', fontsize = 15)
plt.legend()
plt.show()

# %%
mc = pd.crosstab(data['maint'], data['class'])
mc.div(mc.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = True, figsize = (10, 7))

plt.title('Stacked Bar Graph to Depict portions of class taken on each Maint', fontsize = 20)
plt.xlabel('Maint in Increasing Order', fontsize = 15)
plt.ylabel('Count', fontsize = 15)
plt.legend()
plt.show()

# %%
safety = pd.crosstab(data['safety'], data['class'])
safety.div(safety.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = True, figsize = (10, 7))

plt.title('Stacked Bar Graph to Depict portions of class taken on each Safety Category', fontsize = 20)
plt.xlabel('Safety Increasing Order', fontsize = 15)
plt.ylabel('Count', fontsize = 15)
plt.legend()
plt.show()

# %%
doors = pd.crosstab(data['doors'], data['class'])
doors.div(doors.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = True, figsize = (10, 7))

plt.title('Stacked Bar Graph to Depict portions of class taken on each doors Category', fontsize = 20)
plt.xlabel('doors in Increasing Order', fontsize = 15)
plt.ylabel('Count', fontsize = 15)
plt.legend()
plt.show()

# %%
capacity = pd.crosstab(data['persons'], data['class'])
capacity.div(capacity.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = True, figsize = (10, 7))

plt.title('Stacked Bar Graph to Depict portions of class taken on each persons Category', fontsize = 20)
plt.xlabel('persons in Increasing Order', fontsize = 15)
plt.ylabel('Count', fontsize = 15)
plt.legend()
plt.show()

# %%
luggage = pd.crosstab(data['lug_boot'], data['class'])
luggage.div(safety.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = True, figsize = (10, 7))

plt.title('Stacked Bar Graph to Depict portions of class taken on each lug_boot Category', fontsize = 20)
plt.xlabel('lug_boot in Increasing Order', fontsize = 15)
plt.ylabel('Count', fontsize = 15)
plt.legend()
plt.show()

# %%
data['class'].value_counts().sort_index()
# Out:
# acc       384
# good       69
# unacc    1209
# vgood      65
# Name: class, dtype: int64

# %%
labels = ['acc', 'good', 'unacc', 'vgood']
colors = ['pink', 'lightblue', 'lightgreen', 'magenta']
size = [384, 69, 1210, 65]
explode = [0.1, 0.1, 0.1, 0.1]

plt.rcParams['figure.figsize'] = (10, 10)
plt.pie(size, labels = labels, colors = colors, explode = explode, shadow = True, autopct = "%.2f%%")
plt.title('A Pie Chart Representing Different Decisions', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %%
# Label Encoding

data['class'].replace(('unacc', 'acc', 'good', 'vgood'), (0, 1, 2, 3), inplace = True)

data['class'].value_counts()
# Out:
# 0    1209
# 1     384
# 2      69
# 3      65
# Name: class, dtype: int64

# %%
data['lug_boot'].value_counts().sort_index()
# Out:
# big      576
# med      576
# small    575
# Name: lug_boot, dtype: int64

# %%
labels = ['big', 'medium', 'small',]
colors = ['red', 'cyan', 'orange']
size = [576, 576, 576]
explode = [0.1, 0.1, 0.1]

plt.rcParams['figure.figsize'] = (10, 10)
plt.pie(size, labels = labels, colors = colors, explode = explode, shadow = True, autopct = '%.2f%%')
plt.title('A Pie Chart Representing Different Luggage boot Sizes', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %%
# label Encoding

data['lug_boot'].replace(('small', 'med', 'big'), (0, 1, 2), inplace = True)

data['lug_boot'].value_counts()
# Out:
# 1    576
# 2    576
# 0    575
# Name: lug_boot, dtype: int64

# %%
data['safety'].value_counts().sort_index()
# Out:
# high    576
# low     575
# med     576
# Name: safety, dtype: int64

# %%
labels = ['high', 'low', 'med']
colors = ['purple', 'cyan', 'lightblue']
size = [576, 576, 576]
explode = [0.1, 0.1, 0.1]

plt.rcParams['figure.figsize'] = (10, 10)
plt.pie(size, labels = labels, colors = colors, explode = explode, shadow = True, autopct = '%.2f%%')
plt.title('A Pie Chart Representing Different Safety Levels', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %%
# label Encoding

data['safety'].replace(('low', 'med', 'high'), (0, 1, 2), inplace = True)

data['safety'].value_counts()
# Out:
# 1    576
# 2    576
# 0    575
# Name: safety, dtype: int64

# %%
data['buying'].value_counts().sort_index()
# Out:
# high     432
# low      432
# med      432
# vhigh    431
# Name: buying, dtype: int64

# %%
labels = ['high', 'low', 'med', 'vhigh']
colors = ['crimson', 'blue', 'lightpink', 'maroon']
size = [432, 432, 432, 432]
explode = [0.1, 0.1, 0.1, 0.1]

plt.rcParams['figure.figsize'] = (8, 8)
plt.pie(size, labels = labels, colors = colors, explode = explode, shadow = True, startangle = 120, autopct = '%1.1f%%')
plt.title('A Pie Chart Representing Different Price Ranges', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %%
# label Encoding

data['buying'].replace(('low', 'med', 'high', 'vhigh'), (0, 1, 2, 3), inplace = True)

data['buying'].value_counts()
# Out:
# 0    432
# 1    432
# 2    432
# 3    431
# Name: buying, dtype: int64

# %%
data['maint'].value_counts().sort_index()
# Out:
# high     432
# low      432
# med      432
# vhigh    431
# Name: maint, dtype: int64

# %%
labels = ['high', 'low', 'med', 'vhigh']
colors = ['crimson', 'orange', 'red', 'pink']
size = [432, 432, 432, 432]
explode = [0.1, 0.1, 0.1, 0.1]

plt.rcParams['figure.figsize'] = (8, 8)
plt.pie(size, labels = labels, colors = colors, explode = explode, autopct='%1.1f%%', shadow = True, startangle = 120)
plt.title('A Pie Chart Representing Different Maintenance Cost Ranges', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %%
# label Encoding

data['maint'].replace(('low', 'med', 'high', 'vhigh'), (0, 1, 2, 3), inplace = True)

data['maint'].value_counts()
# Out:
# 0    432
# 1    432
# 2    432
# 3    431
# Name: maint, dtype: int64

# %%
data['doors'].value_counts().sort_index()
# Out:
# 2        431
# 3        432
# 4        432
# 5more    432
# Name: doors, dtype: int64

# %%
labels = ['high', 'low', 'med', 'vhigh']
colors = ['yellow', 'orange', 'green', 'pink']
size = [432, 432, 432, 432]
explode = [0.1, 0.1, 0.1, 0.1]

plt.rcParams['figure.figsize'] = (8, 8)
plt.pie(size, labels = labels, colors = colors, explode = explode, autopct='%1.1f%%', shadow = True, startangle = 120)
plt.title('A Pie Chart Representing Different no. of doors', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %%
# label Encoding

data['doors'].replace('5more', 5, inplace = True)

data['doors'].value_counts()
# Out:
# 5    432
# 4    432
# 3    432
# 2    431
# Name: doors, dtype: int64

# %%
data['persons'].value_counts().sort_index()
# Out:
# 2       575
# 4       576
# more    576
# Name: persons, dtype: int64

# %%
labels = ['2', '3', 'more']
colors = ['crimson', 'lightblue', 'lightgreen']
size = [576, 576, 576]
explode = [0.1, 0.1, 0.1]

plt.rcParams['figure.figsize'] = (8, 8)
plt.pie(size, labels = labels, colors = colors, explode = explode, autopct='%1.1f%%', shadow = True, startangle = 120)
plt.title('A Pie Chart Representing Different Capacities', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %%
# label Encoding

data['persons'].replace('more', 5, inplace = True)

data['persons'].value_counts()
# Out:
# 5    576
# 4    576
# 2    575
# Name: persons, dtype: int64

# %%
data.head()
# Out:
#    buying  maint doors persons  lug_boot  safety  class
# 0       3      3     2       2         0       1      0
# 1       3      3     2       2         0       2      0
# 2       3      3     2       2         1       0      0
# 3       3      3     2       2         1       1      0
# 4       3      3     2       2         1       2      0

# %% [markdown]
# # splitting the dataset

# %%
# splitting the dataset into dependent and independent variables

x = data.iloc[:,:6]
y = data.iloc[:, 6]

print("Shape of x: ", x.shape)
print("Shape of y: ", y.shape)
# Out:
# Shape of x:  (1727, 6)
# Shape of y:  (1727,)

# %%
# Label Encoding once more so that we get higher accuracy
# we have 4 classes namely 0, 1, 2, 3
# It would be very beneficial if we combine 0 and 1 as 0 and 1 and 2 as 1

data['class'].replace((0, 1, 2, 3), (0, 0, 1, 1), inplace = True)

data['class'].value_counts()
# Out:
# 0    1593
# 1     134
# Name: class, dtype: int64

# %%
# splitting the dataset into train and test sets

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.15, random_state = 0)

print("Shape of x_train: ", x_train.shape)
print("Shape of y_train: ", y_train.shape)
print("shape of x_test: ", x_test.shape)
print("shape of y_test: ", y_test.shape)
# Out:
# Shape of x_train:  (1467, 6)
# Shape of y_train:  (1467,)
# shape of x_test:  (260, 6)
# shape of y_test:  (260,)

# %%
# standardization

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# # Modelling

# %% [markdown]
# # Logistic Regression

# %%
#importing libraries
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

# creating a model
model = LogisticRegression(C = 1)
# feeding the training data into the model
model.fit(x_train, y_train)

# predicting the values for x-test
y_pred = model.predict(x_test)

# finding the training and testing accuracy
print("Training Accuracy: ",model.score(x_train, y_train))
print("Testing Accuracy: ", model.score(x_test, y_test))

# printing the confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Training Accuracy:  0.9659168370824812
# Testing Accuracy:  0.9730769230769231
# [[239   1]
#  [  6  14]]

# %% [markdown]
# # Decision Trees with max_depth = 3

# %%
#importing libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

# creating a model
model = DecisionTreeClassifier(max_depth = 3)
# feeding the training data into the model
model.fit(x_train, y_train)

# predicting the values for x-test
y_pred = model.predict(x_test)

# finding the training and testing accuracy
print("Training Accuracy: ",model.score(x_train, y_train))
print("Testing Accuracy: ", model.score(x_test, y_test))

# printing the confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Training Accuracy:  0.9222903885480572
# Testing Accuracy:  0.9230769230769231
# [[240   0]
#  [ 20   0]]

# %% [markdown]
# # Decision Tree with max_depth = 2

# %%
#importing libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

# creating a model
model = DecisionTreeClassifier(max_depth = 2)
# feeding the training data into the model
model.fit(x_train, y_train)

# predicting the values for x-test
y_pred = model.predict(x_test)

# finding the training and testing accuracy
print("Training Accuracy: ",model.score(x_train, y_train))
print("Testing Accuracy: ", model.score(x_test, y_test))

# printing the confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Training Accuracy:  0.9222903885480572
# Testing Accuracy:  0.9230769230769231
# [[240   0]
#  [ 20   0]]

# %% [markdown]
# # Decision Tree with max_depth = 4

# %%
#importing libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

# creating a model
model = DecisionTreeClassifier(max_depth = 4)
# feeding the training data into the model
model.fit(x_train, y_train)

# predicting the values for x-test
y_pred = model.predict(x_test)

# finding the training and testing accuracy
print("Training Accuracy: ",model.score(x_train, y_train))
print("Testing Accuracy: ", model.score(x_test, y_test))

# printing the confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Training Accuracy:  0.950920245398773
# Testing Accuracy:  0.9538461538461539
# [[228  12]
#  [  0  20]]

# %% [markdown]
# # Decision Trees with max depth 5

# %%
#importing libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

# creating a model
model = DecisionTreeClassifier(max_depth = 5)
# feeding the training data into the model
model.fit(x_train, y_train)

# predicting the values for x-test
y_pred = model.predict(x_test)

# finding the training and testing accuracy
print("Training Accuracy: ",model.score(x_train, y_train))
print("Testing Accuracy: ", model.score(x_test, y_test))

# printing the confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Training Accuracy:  0.9631901840490797
# Testing Accuracy:  0.9692307692307692
# [[234   6]
#  [  2  18]]

# %% [markdown]
# # Decision Tree with max depth = 6

# %%
#importing libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

# creating a model
model = DecisionTreeClassifier(max_depth = 6)
# feeding the training data into the model
model.fit(x_train, y_train)

# predicting the values for x-test
y_pred = model.predict(x_test)

# finding the training and testing accuracy
print("Training Accuracy: ",model.score(x_train, y_train))
print("Testing Accuracy: ", model.score(x_test, y_test))

# printing the confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Training Accuracy:  0.9706884798909339
# Testing Accuracy:  0.9730769230769231
# [[233   7]
#  [  0  20]]

# %% [markdown]
# # Decision Tree with max depth = 7`

# %%
#importing libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

# creating a model
model = DecisionTreeClassifier(max_depth = 7)
# feeding the training data into the model
model.fit(x_train, y_train)

# predicting the values for x-test
y_pred = model.predict(x_test)

# finding the training and testing accuracy
print("Training Accuracy: ",model.score(x_train, y_train))
print("Testing Accuracy: ", model.score(x_test, y_test))

# printing the confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Training Accuracy:  0.9795501022494888
# Testing Accuracy:  0.9846153846153847
# [[238   2]
#  [  2  18]]

# %% [markdown]
# # Decision Tree with max depth = 8

# %%
#importing libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

# creating a model
model = DecisionTreeClassifier(max_depth = 8)
# feeding the training data into the model
model.fit(x_train, y_train)

# predicting the values for x-test
y_pred = model.predict(x_test)

# finding the training and testing accuracy
print("Training Accuracy: ",model.score(x_train, y_train))
print("Testing Accuracy: ", model.score(x_test, y_test))

# printing the confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Training Accuracy:  0.989093387866394
# Testing Accuracy:  0.9923076923076923
# [[238   2]
#  [  0  20]]

# %% [markdown]
# # Decision Tree with max depth = 9

# %%
#importing libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

# creating a model
model = DecisionTreeClassifier(max_depth = 9)
# feeding the training data into the model
model.fit(x_train, y_train)

# predicting the values for x-test
y_pred = model.predict(x_test)

# finding the training and testing accuracy
print("Training Accuracy: ",model.score(x_train, y_train))
print("Testing Accuracy: ", model.score(x_test, y_test))

# printing the confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Training Accuracy:  0.9938650306748467
# Testing Accuracy:  0.9884615384615385
# [[239   1]
#  [  2  18]]

# %% [markdown]
# # Decsision Tree with max depth =10

# %%
#importing libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

# creating a model
model_d10 = DecisionTreeClassifier(max_depth = 10)
# feeding the training data into the model
model_d10.fit(x_train, y_train)

# predicting the values for x-test
y_pred = model_d10.predict(x_test)

# finding the training and testing accuracy
print("Training Accuracy: ",model_d10.score(x_train, y_train))
print("Testing Accuracy: ", model_d10.score(x_test, y_test))

# printing the confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Training Accuracy:  0.9979550102249489
# Testing Accuracy:  0.9923076923076923
# [[239   1]
#  [  1  19]]

# %% [markdown]
# # using default value of max_depth We are getting the best result of 98.07% accuracy over the test set

# %%
#importing libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

# creating a model
model = DecisionTreeClassifier()
# feeding the training data into the model
model.fit(x_train, y_train)

# predicting the values for x-test
y_pred = model.predict(x_test)

# finding the training and testing accuracy
print("Training Accuracy: ",model.score(x_train, y_train))
print("Testing Accuracy: ", model.score(x_test, y_test))

# printing the confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.9961538461538462
# [[240   0]
#  [  1  19]]

# %%
#  plotting the graph for performance of decision trees with different max_depth values

max_depth = np.array([2, 3, 4, 5, 6, 7, 8, 9, 10])
Training_Accuracy = np.array([93.4, 93.5, 97.3, 97.3, 94.6, 97.3, 97.3, 98.4, 98.07])
Testing_Accuracy = np.array([92.02, 92.02, 95.9, 95.9, 97.8, 98.4, 99.3, 99.7, 100.0])

plt.rcParams['figure.figsize'] = (10, 7)
plt.plot(max_depth, Training_Accuracy, 'r--')
plt.plot(max_depth, Testing_Accuracy, 'b-*')
plt.title('Performance of Decision Tree with Different Values of max depth', fontsize = 20)
plt.xlim([1, 11])
plt.ylim([90, 100])
plt.xlabel('Max Depth ', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Random Forest

# %%
#importing libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

# creating a model
model = RandomForestClassifier()
# feeding the training data into the model
model.fit(x_train, y_train)

# predicting the values for x-test
y_pred = model.predict(x_test)

# finding the training and testing accuracy
print("Training Accuracy: ",model.score(x_train, y_train))
print("Testing Accuracy: ", model.score(x_test, y_test))

# printing the confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.9961538461538462
# [[240   0]
#  [  1  19]]

# %%
# checking the feature importance

imp = model.feature_importances_

print(imp)
# Out:
# [0.25216355 0.21030776 0.06214    0.17723925 0.10129459 0.19685486]

# %% [markdown]
# # KNN Classifiers

# %%
# feeding the training data into the model
model.fit(x_train, y_train)

# predicting the values for x-test
y_pred = model.predict(x_test)

# finding the training and testing accuracy
print("Training Accuracy: ",model.score(x_train, y_train))
print("Testing Accuracy: ", model.score(x_test, y_test))

# printing the confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.9923076923076923
# [[239   1]
#  [  1  19]]

# %% [markdown]
# # Save best model

# %%
import pickle

with open('Car Evaluation Project', 'wb') as file:
    pickle.dump(model_d10, file)
